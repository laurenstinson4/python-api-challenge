# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as sts
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['punta arenas', 'mataura', 'voi', 'lulea', 'victoria', 'vaitupu', 'bredasdorp', 'hilo', 'atuona', 'mys shmidta', 'severo-kurilsk', 'tuatapere', 'amethi', 'tsihombe', 'sentyabrskiy', 'astorga', 'hithadhoo', 'ushuaia', 'arraial do cabo', 'tawkar', 'butaritari', 'kimbe', 'iralaya', 'warqla', 'newport', 'changji', 'oktyabrskaya', 'hobart', 'te anau', 'zeya', 'kirakira', 'hami', 'nishihara', 'lavrentiya', 'coahuayana', 'tasbuget', 'santo antonio do leverger', 'vaini', 'rikitea', 'carnarvon', 'amderma', 'kapaa', 'port alfred', 'bayanday', 'ponta do sol', 'bela vista', 'vrangel', 'bilma', 'saleaula', 'illoqqortoormiut', 'grand river south east', 'spearfish', 'taolanaro', 'mukhen', 'miandrivazo', 'avarua', 'svetlyy', 'caucaia', 'bluff', 'stoyba', 'faanui', 'ipoh', 'kaitangata', 'guangyuan', 'cape town', 'puerto ayora', 'deder', 'jamestown', 'pangnirtung', 'koslan', 'rokytne', 'bastia', 'woodburn', 'castro', 'talnakh', 'turayf', 'baykit', 'port elizabeth', 'rincon', 'taree', 'hervey bay', 'mahebourg', 'chokurdakh', 'kovdor', 'sandakan', 'galle', 'yellowknife', 'codrington', 'bandarban', 'kinango', 'ocampo', 'barrow', 'douglas', 'dikson', 'belushya guba', 'kapit', 'beringovskiy', 'bethel', 'sept-iles', 'constitucion', 'thinadhoo', 'nikolskoye', 'sambava', 'booue', 'albany', 'busselton', 'new norfolk', 'san quintin', 'alice springs', 'upernavik', 'saint george', 'cherskiy', 'lamar', 'chuy', 'staryy nadym', 'poronaysk', 'jiblah', 'tikrit', 'namibe', 'saint-philippe', 'hermanus', 'comarapa', 'saint-georges', 'lebu', 'esperance', 'port lincoln', 'georgetown', 'verkhnetulomskiy', 'umzimvubu', 'krasnotorka', 'leh', 'tuktoyaktuk', 'yulara', 'qaqortoq', 'surt', 'severobaykalsk', 'moron', 'yaan', 'pisco', 'yanan', 'longyearbyen', 'natal', 'celestun', 'bati', 'vilyuysk', 'boleslawiec', 'salair', 'saint-augustin', 'aneho', 'svencionys', 'ijaki', 'barentsburg', 'yongan', 'puerto el triunfo', 'batagay', 'kodiak', 'crab hill', 'hofn', 'vanavara', 'luan', 'puerto quijarro', 'mar del plata', 'pevek', 'jumla', 'umm kaddadah', 'salalah', 'usinsk', 'calvinia', 'kahului', 'san cristobal', 'homer', 'isangel', 'nizhneyansk', 'cairns', 'college place', 'sivaki', 'east london', 'yenagoa', 'lasa', 'boende', 'lompoc', 'trincomalee', 'sola', 'henties bay', 'shambu', 'pabna', 'punta cardon', 'junin', 'tymovskoye', 'nanortalik', 'brigantine', 'suntar', 'arlit', 'kavieng', 'mount gambier', 'west wendover', 'chokwe', 'port hawkesbury', 'colchester', 'provideniya', 'nichinan', 'kutum', 'edmundston', 'east wenatchee bench', 'ilulissat', 'alotau', 'ribeira grande', 'qaanaaq', 'mehamn', 'khatanga', 'sumbe', 'blagoyevo', 'manzhouli', 'den helder', 'lorica', 'kavaratti', 'saint anthony', 'frontignan', 'bosaso', 'vestbygda', 'clyde river', 'sobolevo', 'ancud', 'torbay', 'saskylakh', 'asau', 'cochrane', 'nantucket', 'aklavik', 'thompson', 'denpasar', 'erdenet', 'tawnat', 'prince rupert', 'hasaki', 'churapcha', 'planaltina', 'inuvik', 'portland', 'palabuhanratu', 'bjornevatn', 'tabou', 'acapulco', 'luangwa', 'merauke', 'novosmolinskiy', 'lata', 'cockburn town', 'bambous virieux', 'port-gentil', 'paucartambo', 'rongcheng', 'coquimbo', 'along', 'rio brilhante', 'klaksvik', 'huarmey', 'zhoucheng', 'lazo', 'leningradskiy', 'santa rosa', 'juri', 'paamiut', 'cidreira', 'samoded', 'ostrovnoy', 'kaupanger', 'tura', 'joshimath', 'tamworth', 'klyuchi', 'toliary', 'trinidad', 'cabanas', 'indramayu', 'necochea', 'guerrero negro', 'petropavlovsk-kamchatskiy', 'el seibo', 'tutoia', 'muros', 'nemuro', 'samarai', 'dire', 'vostok', 'katsuura', 'riviere-au-renard', 'namatanai', 'gizo', 'haines junction', 'olinda', 'lodja', 'buon me thuot', 'san lorenzo', 'katakwi', 'vestmannaeyjar', 'barra do garcas', 'joensuu', 'pozo colorado', 'mgandu', 'byron bay', 'ayan', 'sao filipe', 'corrales', 'klimovo', 'road town', 'kashi', 'guapo', 'walvis bay', 'patea', 'dwarka', 'utiroa', 'nelson bay', 'baturite', 'hamilton', 'geraldton', 'viedma', 'kuching', 'tasiilaq', 'makaryev', 'batemans bay', 'shimoda', 'za ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL formatting
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#Beginning data for loop
citynumber = 1
weather_data = []
names = []
latitudes = []
longitudes = []
max_temps = []
humidities = []
clouds = []
winds = []
countries = []
dates = []

#Print header
print("Beginning Data Retrieval")
print("-----------------------------")

#For loop to pull in data from API
for city in cities:
    response = requests.get(query_url + city).json()
    #use an exception to allow code to continue in case of error
    try:
        names.append(response['name'])
        latitudes.append(response['coord']['lat'])
        longitudes.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        humidities.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        winds.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
    
        print(f"Processing Record {citynumber} | {city}")
    
    except:
        print("That city does not exist.")

    
    citynumber = citynumber + 1

#End of print-out so user knows data retrieval is complete
print("All records processed.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | punta arenas
# Processing Record 2 | mataura
# Processing Record 3 | voi
# Processing Record 4 | lulea
# Processing Record 5 | victoria
# That city does not exist.
# Processing Record 7 | bredasdorp
# Processing Record 8 | hilo
# Processing Record 9 | atuona
# That city does not exist.
# Processing Record 11 | severo-kurilsk
# Processing Record 12 | tuatapere
# Processing Record 13 | amethi
# That city does not exist.
# That city does not exist.
# Processing Record 16 | astorga
# Processing Record 17 | hithadhoo
# Processing Record 18 | ushuaia
# Processing Record 19 | arraial do cabo
# That city does not exist.
# Processing Record 21 | butaritari
# Processing Record 22 | kimbe
# Processing Record 23 | iralaya
# That city does not exist.
# Processing Record 25 | newport
# Processing Record 26 | changji
# That city does not exist.
# Processing Record 28 | hobart
# Processing Record 29 | te anau
# Processing Record 30 | zeya
# Processing Record 31 | kirakira
# Processing Record 32 | hami
# Processing Record 33 | nishihara
# Processing Record 34 | lavrentiya
# Processing Record 35 | coahuayana
# That city does not exist.
# Processing Record 37 | santo antonio do leverger
# Processing Record 38 | vaini
# Processing Record 39 | rikitea
# Processing Record 40 | carnarvon
# That city does not exist.
# Processing Record 42 | kapaa
# Processing Record 43 | port alfred
# Processing Record 44 | bayanday
# Processing Record 45 | ponta do sol
# Processing Record 46 | bela vista
# Processing Record 47 | vrangel
# Processing Record 48 | bilma
# That city does not exist.
# That city does not exist.
# That city does not exist.
# Processing Record 52 | spearfish
# That city does not exist.
# Processing Record 54 | mukhen
# Processing Record 55 | miandrivazo
# Processing Record 56 | avarua
# Processing Record 57 | svetlyy
# Processing Record 58 | caucaia
# Processing Record 59 | bluff
# That city does not exist.
# Processing Record 61 | faanui
# Processing Record 62 | ipoh
# Processing Record 63 | kaitangata
# Processing Record 64 | guangyuan
# Processing Record 65 | cape town
# Processing Record 66 | puerto ayora
# Processing Record 67 | deder
# Processing Record 68 | jamestown
# Processing Record 69 | pangnirtung
# Processing Record 70 | koslan
# Processing Record 71 | rokytne
# Processing Record 72 | bastia
# Processing Record 73 | woodburn
# Processing Record 74 | castro
# Processing Record 75 | talnakh
# Processing Record 76 | turayf
# Processing Record 77 | baykit
# Processing Record 78 | port elizabeth
# Processing Record 79 | rincon
# Processing Record 80 | taree
# Processing Record 81 | hervey bay
# Processing Record 82 | mahebourg
# Processing Record 83 | chokurdakh
# Processing Record 84 | kovdor
# Processing Record 85 | sandakan
# Processing Record 86 | galle
# Processing Record 87 | yellowknife
# Processing Record 88 | codrington
# Processing Record 89 | bandarban
# Processing Record 90 | kinango
# Processing Record 91 | ocampo
# Processing Record 92 | barrow
# Processing Record 93 | douglas
# Processing Record 94 | dikson
# That city does not exist.
# Processing Record 96 | kapit
# Processing Record 97 | beringovskiy
# Processing Record 98 | bethel
# Processing Record 99 | sept-iles
# Processing Record 100 | constitucion
# Processing Record 101 | thinadhoo
# Processing Record 102 | nikolskoye
# Processing Record 103 | sambava
# Processing Record 104 | booue
# Processing Record 105 | albany
# Processing Record 106 | busselton
# Processing Record 107 | new norfolk
# Processing Record 108 | san quintin
# Processing Record 109 | alice springs
# Processing Record 110 | upernavik
# Processing Record 111 | saint george
# Processing Record 112 | cherskiy
# Processing Record 113 | lamar
# Processing Record 114 | chuy
# Processing Record 115 | staryy nadym
# Processing Record 116 | poronaysk
# Processing Record 117 | jiblah
# Processing Record 118 | tikrit
# Processing Record 119 | namibe
# Processing Record 120 | saint-philippe
# Processing Record 121 | hermanus
# Processing Record 122 | comarapa
# Processing Record 123 | saint-georges
# Processing Record 124 | lebu
# Processing Record 125 | esperance
# Processing Record 126 | port lincoln
# Processing Record 127 | georgetown
# Processing Record 128 | verkhnetulomskiy
# That city does not exist.
# Processing Record 130 | krasnotorka
# Processing Record 131 | leh
# Processing Record 132 | tuktoyaktuk
# Processing Record 133 | yulara
# Processing Record 134 | qaqortoq
# Processing Record 135 | surt
# Processing Record 136 | severobaykalsk
# Processing Record 137 | moron
# Processing Record 138 | yaan
# Processing Record 139 | pisco
# That city does not exist.
# Processing Record 141 | longyearbyen
# Processing Record 142 | natal
# Processing Record 143 | celestun
# Processing Record 144 | bati
# Processing Record 145 | vilyuysk
# Processing Record 146 | boleslawiec
# Processing Record 147 | salair
# Processing Record 148 | saint-augustin
# Processing Record 149 | aneho
# Processing Record 150 | svencionys
# That city does not exist.
# That city does not exist.
# Processing Record 153 | yongan
# Processing Record 154 | puerto el triunfo
# Processing Record 155 | batagay
# Processing Record 156 | kodiak
# That city does not exist.
# Processing Record 158 | hofn
# Processing Record 159 | vanavara
# Processing Record 160 | luan
# Processing Record 161 | puerto quijarro
# Processing Record 162 | mar del plata
# Processing Record 163 | pevek
# Processing Record 164 | jumla
# Processing Record 165 | umm kaddadah
# Processing Record 166 | salalah
# Processing Record 167 | usinsk
# Processing Record 168 | calvinia
# Processing Record 169 | kahului
# Processing Record 170 | san cristobal
# Processing Record 171 | homer
# Processing Record 172 | isangel
# That city does not exist.
# Processing Record 174 | cairns
# Processing Record 175 | college place
# Processing Record 176 | sivaki
# Processing Record 177 | east london
# Processing Record 178 | yenagoa
# Processing Record 179 | lasa
# Processing Record 180 | boende
# Processing Record 181 | lompoc
# Processing Record 182 | trincomalee
# Processing Record 183 | sola
# Processing Record 184 | henties bay
# Processing Record 185 | shambu
# Processing Record 186 | pabna
# Processing Record 187 | punta cardon
# Processing Record 188 | junin
# Processing Record 189 | tymovskoye
# Processing Record 190 | nanortalik
# Processing Record 191 | brigantine
# Processing Record 192 | suntar
# Processing Record 193 | arlit
# Processing Record 194 | kavieng
# Processing Record 195 | mount gambier
# Processing Record 196 | west wendover
# Processing Record 197 | chokwe
# Processing Record 198 | port hawkesbury
# Processing Record 199 | colchester
# Processing Record 200 | provideniya
# Processing Record 201 | nichinan
# Processing Record 202 | kutum
# Processing Record 203 | edmundston
# Processing Record 204 | east wenatchee bench
# Processing Record 205 | ilulissat
# That city does not exist.
# Processing Record 207 | ribeira grande
# Processing Record 208 | qaanaaq
# Processing Record 209 | mehamn
# Processing Record 210 | khatanga
# Processing Record 211 | sumbe
# Processing Record 212 | blagoyevo
# Processing Record 213 | manzhouli
# Processing Record 214 | den helder
# Processing Record 215 | lorica
# Processing Record 216 | kavaratti
# Processing Record 217 | saint anthony
# Processing Record 218 | frontignan
# Processing Record 219 | bosaso
# That city does not exist.
# Processing Record 221 | clyde river
# Processing Record 222 | sobolevo
# Processing Record 223 | ancud
# Processing Record 224 | torbay
# Processing Record 225 | saskylakh
# Processing Record 226 | asau
# Processing Record 227 | cochrane
# Processing Record 228 | nantucket
# Processing Record 229 | aklavik
# Processing Record 230 | thompson
# Processing Record 231 | denpasar
# Processing Record 232 | erdenet
# That city does not exist.
# Processing Record 234 | prince rupert
# Processing Record 235 | hasaki
# Processing Record 236 | churapcha
# Processing Record 237 | planaltina
# Processing Record 238 | inuvik
# Processing Record 239 | portland
# That city does not exist.
# Processing Record 241 | bjornevatn
# Processing Record 242 | tabou
# Processing Record 243 | acapulco
# Processing Record 244 | luangwa
# Processing Record 245 | merauke
# Processing Record 246 | novosmolinskiy
# Processing Record 247 | lata
# Processing Record 248 | cockburn town
# Processing Record 249 | bambous virieux
# Processing Record 250 | port-gentil
# That city does not exist.
# Processing Record 252 | rongcheng
# Processing Record 253 | coquimbo
# Processing Record 254 | along
# Processing Record 255 | rio brilhante
# Processing Record 256 | klaksvik
# Processing Record 257 | huarmey
# Processing Record 258 | zhoucheng
# Processing Record 259 | lazo
# Processing Record 260 | leningradskiy
# Processing Record 261 | santa rosa
# Processing Record 262 | juri
# Processing Record 263 | paamiut
# Processing Record 264 | cidreira
# Processing Record 265 | samoded
# Processing Record 266 | ostrovnoy
# Processing Record 267 | kaupanger
# Processing Record 268 | tura
# Processing Record 269 | joshimath
# Processing Record 270 | tamworth
# Processing Record 271 | klyuchi
# That city does not exist.
# Processing Record 273 | trinidad
# Processing Record 274 | cabanas
# Processing Record 275 | indramayu
# Processing Record 276 | necochea
# Processing Record 277 | guerrero negro
# Processing Record 278 | petropavlovsk-kamchatskiy
# Processing Record 279 | el seibo
# Processing Record 280 | tutoia
# Processing Record 281 | muros
# Processing Record 282 | nemuro
# Processing Record 283 | samarai
# Processing Record 284 | dire
# Processing Record 285 | vostok
# Processing Record 286 | katsuura
# Processing Record 287 | riviere-au-renard
# Processing Record 288 | namatanai
# Processing Record 289 | gizo
# Processing Record 290 | haines junction
# Processing Record 291 | olinda
# Processing Record 292 | lodja
# That city does not exist.
# Processing Record 294 | san lorenzo
# Processing Record 295 | katakwi
# Processing Record 296 | vestmannaeyjar
# Processing Record 297 | barra do garcas
# Processing Record 298 | joensuu
# Processing Record 299 | pozo colorado
# Processing Record 300 | mgandu
# Processing Record 301 | byron bay
# Processing Record 302 | ayan
# Processing Record 303 | sao filipe
# Processing Record 304 | corrales
# Processing Record 305 | klimovo
# Processing Record 306 | road town
# Processing Record 307 | kashi
# Processing Record 308 | guapo
# Processing Record 309 | walvis bay
# Processing Record 310 | patea
# Processing Record 311 | dwarka
# That city does not exist.
# Processing Record 313 | nelson bay
# Processing Record 314 | baturite
# Processing Record 315 | hamilton
# Processing Record 316 | geraldton
# Processing Record 317 | viedma
# Processing Record 318 | kuching
# Processing Record 319 | tasiilaq
# Processing Record 320 | makaryev
# Processing Record 321 | batemans bay
# Processing Record 322 | shimoda
# Processing Record 323 | zabid
# Processing Record 324 | nouadhibou
# Processing Record 325 | hambantota
# Processing Record 326 | pingliang
# Processing Record 327 | batagay-alyta
# Processing Record 328 | yar-sale
# Processing Record 329 | komsomolskiy
# Processing Record 330 | aykhal
# Processing Record 331 | awbari
# Processing Record 332 | grand-lahou
# Processing Record 333 | alugan
# Processing Record 334 | bathsheba
# Processing Record 335 | beloha
# Processing Record 336 | port macquarie
# Processing Record 337 | christchurch
# Processing Record 338 | selikhino
# Processing Record 339 | jutai
# Processing Record 340 | bowen
# Processing Record 341 | rio grande
# Processing Record 342 | bengkulu
# Processing Record 343 | shingu
# Processing Record 344 | tomatlan
# Processing Record 345 | meulaboh
# Processing Record 346 | changping
# Processing Record 347 | riyadh
# Processing Record 348 | souillac
# Processing Record 349 | hakkari
# Processing Record 350 | salekhard
# Processing Record 351 | marsa matruh
# Processing Record 352 | chapais
# Processing Record 353 | terrace
# Processing Record 354 | summerside
# Processing Record 355 | bulgan
# Processing Record 356 | shenjiamen
# Processing Record 357 | pyapon
# Processing Record 358 | puerto narino
# Processing Record 359 | calderitas
# Processing Record 360 | lorengau
# Processing Record 361 | westport
# Processing Record 362 | luderitz
# That city does not exist.
# Processing Record 364 | manggar
# Processing Record 365 | caravelas
# Processing Record 366 | bandarbeyla
# Processing Record 367 | grindavik
# Processing Record 368 | iqaluit
# Processing Record 369 | ahipara
# Processing Record 370 | anloga
# Processing Record 371 | canete
# Processing Record 372 | isla mujeres
# Processing Record 373 | tautira
# Processing Record 374 | riberalta
# Processing Record 375 | maiduguri
# Processing Record 376 | huntington beach
# That city does not exist.
# Processing Record 378 | wanning
# Processing Record 379 | dehloran
# Processing Record 380 | sretensk
# Processing Record 381 | chapleau
# Processing Record 382 | miri
# Processing Record 383 | bratsk
# That city does not exist.
# Processing Record 385 | ardabil
# Processing Record 386 | onalaska
# Processing Record 387 | cabo san lucas
# Processing Record 388 | kruisfontein
# Processing Record 389 | shuangyang
# Processing Record 390 | wanaka
# Processing Record 391 | gushikawa
# That city does not exist.
# Processing Record 393 | sarangani
# Processing Record 394 | novyy urgal
# Processing Record 395 | yablonovo
# Processing Record 396 | adrar
# Processing Record 397 | north bend
# Processing Record 398 | forio
# Processing Record 399 | lyngseidet
# Processing Record 400 | nueva armenia
# Processing Record 401 | patiya
# Processing Record 402 | galashki
# Processing Record 403 | pindiga
# Processing Record 404 | pacific grove
# Processing Record 405 | comodoro rivadavia
# Processing Record 406 | coihaique
# Processing Record 407 | serenje
# Processing Record 408 | tilichiki
# Processing Record 409 | fort nelson
# Processing Record 410 | lyuban
# Processing Record 411 | srandakan
# That city does not exist.
# Processing Record 413 | berlevag
# Processing Record 414 | anadyr
# Processing Record 415 | sao jose da coroa grande
# Processing Record 416 | kalabo
# Processing Record 417 | bilibino
# Processing Record 418 | los llanos de aridane
# Processing Record 419 | belaya gora
# Processing Record 420 | waipawa
# Processing Record 421 | ixtapa
# Processing Record 422 | yamoussoukro
# Processing Record 423 | madhupur
# Processing Record 424 | sisimiut
# Processing Record 425 | kupino
# Processing Record 426 | shaunavon
# Processing Record 427 | igra
# Processing Record 428 | okhotsk
# Processing Record 429 | the valley
# Processing Record 430 | borovskoy
# Processing Record 431 | corbu
# Processing Record 432 | ossora
# Processing Record 433 | kumluca
# Processing Record 434 | mizdah
# Processing Record 435 | kenai
# Processing Record 436 | smolenka
# Processing Record 437 | richards bay
# Processing Record 438 | batamshinskiy
# Processing Record 439 | yuxia
# Processing Record 440 | lithakia
# Processing Record 441 | bani
# That city does not exist.
# Processing Record 443 | zhireken
# Processing Record 444 | rustenburg
# Processing Record 445 | san jeronimo
# Processing Record 446 | muzhi
# Processing Record 447 | kaeo
# Processing Record 448 | cayenne
# Processing Record 449 | nome
# That city does not exist.
# That city does not exist.
# Processing Record 452 | manokwari
# Processing Record 453 | daru
# That city does not exist.
# Processing Record 455 | goderich
# Processing Record 456 | flin flon
# Processing Record 457 | chulym
# Processing Record 458 | zmeinogorsk
# Processing Record 459 | alofi
# Processing Record 460 | kariba
# That city does not exist.
# Processing Record 462 | narsaq
# Processing Record 463 | zastron
# Processing Record 464 | kipushi
# Processing Record 465 | port blair
# Processing Record 466 | tucuma
# Processing Record 467 | auki
# That city does not exist.
# Processing Record 469 | avera
# Processing Record 470 | russell
# Processing Record 471 | jibuti
# That city does not exist.
# Processing Record 473 | balakhninskiy
# Processing Record 474 | khandyga
# Processing Record 475 | husavik
# Processing Record 476 | amga
# Processing Record 477 | edd
# Processing Record 478 | nizwa
# Processing Record 479 | tiznit
# Processing Record 480 | prosvet
# Processing Record 481 | lagoa
# Processing Record 482 | atambua
# Processing Record 483 | manavalakurichi
# Processing Record 484 | paysandu
# Processing Record 485 | naze
# Processing Record 486 | west monroe
# Processing Record 487 | eureka
# Processing Record 488 | ampanihy
# Processing Record 489 | garowe
# Processing Record 490 | arak
# Processing Record 491 | tsiroanomandidy
# Processing Record 492 | conde
# Processing Record 493 | raudeberg
# Processing Record 494 | bima
# Processing Record 495 | marystown
# Processing Record 496 | fort frances
# Processing Record 497 | valley station
# Processing Record 498 | wangkui
# Processing Record 499 | deputatskiy
# Processing Record 500 | brae
# Processing Record 501 | vao
# Processing Record 502 | katima mulilo
# Processing Record 503 | rio gallegos
# Processing Record 504 | havelock
# Processing Record 505 | truro
# Processing Record 506 | pagudpud
# Processing Record 507 | elhovo
# Processing Record 508 | inhambane
# Processing Record 509 | saintes
# Processing Record 510 | lavaltrie
# Processing Record 511 | bonavista
# Processing Record 512 | laguna
# Processing Record 513 | grand gaube
# Processing Record 514 | manicore
# That city does not exist.
# Processing Record 516 | umm lajj
# Processing Record 517 | hollins
# Processing Record 518 | lima
# Processing Record 519 | novikovo
# Processing Record 520 | kungurtug
# Processing Record 521 | tran
# Processing Record 522 | norman wells
# Processing Record 523 | nuuk
# That city does not exist.
# Processing Record 525 | itaituba
# Processing Record 526 | kaminskiy
# Processing Record 527 | ames
# Processing Record 528 | matara
# Processing Record 529 | diamantino
# Processing Record 530 | itarema
# Processing Record 531 | businga
# Processing Record 532 | bar harbor
# Processing Record 533 | jaora
# Processing Record 534 | tamale
# Processing Record 535 | kalmunai
# Processing Record 536 | chimbarongo
# Processing Record 537 | kongolo
# Processing Record 538 | yagodnoye
# Processing Record 539 | margate
# Processing Record 540 | tezpur
# Processing Record 541 | zhezkazgan
# Processing Record 542 | kingisepp
# Processing Record 543 | evensk
# That city does not exist.
# Processing Record 545 | sorland
# Processing Record 546 | canora
# Processing Record 547 | tulun
# Processing Record 548 | rawlins
# Processing Record 549 | haapiti
# Processing Record 550 | camacha
# Processing Record 551 | veraval
# Processing Record 552 | tiksi
# Processing Record 553 | hovd
# Processing Record 554 | saint-francois
# Processing Record 555 | mundo nuevo
# Processing Record 556 | safranbolu
# Processing Record 557 | ketchikan
# Processing Record 558 | kologriv
# Processing Record 559 | darnetal
# Processing Record 560 | hobyo
# Processing Record 561 | yumen
# Processing Record 562 | moissala
# Processing Record 563 | lafia
# Processing Record 564 | shawnee
# Processing Record 565 | kant
# Processing Record 566 | maniitsoq
# Processing Record 567 | keetmanshoop
# That city does not exist.
# Processing Record 569 | erzin
# Processing Record 570 | itoman
# Processing Record 571 | iranshahr
# Processing Record 572 | ballina
# That city does not exist.
# Processing Record 574 | port hardy
# That city does not exist.
# Processing Record 576 | foam lake
# Processing Record 577 | asyut
# Processing Record 578 | apricena
# Processing Record 579 | vila velha
# Processing Record 580 | roald
# Processing Record 581 | pinheiro machado
# Processing Record 582 | guerande
# Processing Record 583 | saldanha
# Processing Record 584 | alta floresta
# Processing Record 585 | muroto
# That city does not exist.
# Processing Record 587 | bukama
# That city does not exist.
# Processing Record 589 | envira
# Processing Record 590 | southbridge
# Processing Record 591 | villa bruzual
# That city does not exist.
# Processing Record 593 | touros
# Processing Record 594 | lichtenfels
# Processing Record 595 | vitoria de santo antao
# Processing Record 596 | praia
# Processing Record 597 | faya
# Processing Record 598 | soure
# Processing Record 599 | khani
# Processing Record 600 | gubskaya
# Processing Record 601 | vila franca do campo
# Processing Record 602 | srednekolymsk
# Processing Record 603 | palora
# That city does not exist.
# That city does not exist.
# Processing Record 606 | machinga
# Processing Record 607 | pemberton
# Processing Record 608 | egvekinot
# Processing Record 609 | varniai
# Processing Record 610 | lewistown
# Processing Record 611 | ambulu
# Processing Record 612 | tadpatri
# Processing Record 613 | goundi
# Processing Record 614 | airai
# Processing Record 615 | nadiad
# Processing Record 616 | college
# Processing Record 617 | kualakapuas
# Processing Record 618 | half moon bay
# Processing Record 619 | sitka
# Processing Record 620 | lebyazhye
# Processing Record 621 | fairbanks
# Processing Record 622 | ca mau
# All records processed.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a dictionary
weather_dictionary = {
    "City": names,
    "Lat": latitudes,
    "Lng": longitudes,
    "Max Temp": max_temps,
    "Humidity": humidities,
    "Cloudiness": clouds,
    "Wind Speed": winds,
    "Country": countries,
    "Date": dates
}

#pull dictionary into data frame
weather_df = pd.DataFrame(weather_dictionary)
weather_df.to_csv(output_data_file)
weather_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas -53.1500  -70.9167     14.00        51          75
# 1          Mataura -46.1927  168.8643     20.87        57           0
# 2              Voi  -3.3945   38.5630     23.51        79          63
# 3            Luleå  65.5842   22.1547    -11.00        92          40
# 4        Hong Kong  22.2855  114.1577     18.89        64           0
# ..             ...      ...       ...       ...       ...         ...
# 565  Half Moon Bay  37.4636 -122.4286     19.00        72           1
# 566          Sitka  57.0531 -135.3300      2.00        69          40
# 567     Lebyazh'ye  55.2689   66.4947      0.62        97         100
# 568      Fairbanks  64.8378 -147.7164    -21.11        77          90
# 569         Ca Mau   9.1769  105.1500     22.50        89          88
#
#      Wind Speed Country        Date
# 0         10.80      CL  1612649287
# 1          0.94      NZ  1612649114
# 2          1.64      KE  1612649287
# 3          5.66      SE  1612649287
# 4          2.25      HK  1612649287
# ..          ...     ...         ...
# 565        1.90      US  1612649140
# 566        6.69      US  1612649343
# 567        6.91      RU  1612649343
# 568        0.39      US  1612649044
# 569        0.43      VN  1612649344
#
# [570 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_data = weather_df.query('Humidity > 100').index.tolist()

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
if not humidity_data:
    print("All humidities less than or equal to 100%.")

else:
    for i in humidity_data:
        weather_df.drop(index=[i], axis=0, inplace=True)
# Out:
# All humidities less than or equal to 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Max Temp'], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (02/02/2021)")
plt.grid()

plt.savefig('output_data/Latitude_vs_Temperature_Plot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Humidity'], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (02/02/2021)")
plt.grid()

plt.savefig('output_data/Latitude_vs_Humidity_Plot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (02/02/2021)")
plt.grid()

plt.savefig('output_data/Latitude_vs_Cloudiness_Plot.png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Wind Speed'], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (02/02/2021)")
plt.grid()

plt.savefig('output_data/Latitude_vs_WindSpeed_Plot.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_weather_df = weather_df[weather_df.Lat >= 0]
southern_weather_df = weather_df[weather_df.Lat <= 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set axises 
x_axis1 = northern_weather_df['Lat']
y_axis1 = northern_weather_df['Max Temp']

# Correlation equation
correlation1 = sts.pearsonr(x_axis1, y_axis1)
print(f"The r-value is: {round(correlation1[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis1, y_axis1)

# Calculate the regression line
regression_line = x_axis1 * slope + intercept

# Calculate the linear equation
linear_equation = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis1, y_axis1)

# Plot the regression line on top of scatterplot
plt.plot(x_axis1, regression_line, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation, (38,8), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern Hemisphere City Latitude vs. Max Temperature (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Northern_Hemisphere_Latitude_vs_Temperature_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: -0.844569

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set axises 
x_axis2 = southern_weather_df['Lat']
y_axis2 = southern_weather_df['Max Temp']

# Correlation equation
correlation2 = sts.pearsonr(x_axis2, y_axis2)
print(f"The r-value is: {round(correlation2[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis2, y_axis2)

# Calculate the regression line
regression_line2 = x_axis2 * slope + intercept

# Calculate the linear equation
linear_equation2 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis2, y_axis2)

# Plot the regression line on top of scatterplot
plt.plot(x_axis2, regression_line2, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation2, (-30,26), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern Hemisphere City Latitude vs. Max Temperature (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Southern_Hemisphere_Latitude_vs_Temperature_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.56999

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis3 = northern_weather_df['Lat']
y_axis3 = northern_weather_df['Humidity']

# Correlation equation
correlation3 = sts.pearsonr(x_axis3, y_axis3)
print(f"The r-value is: {round(correlation3[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis3, y_axis3)

# Calculate the regression line
regression_line3 = x_axis3 * slope + intercept

# Calculate the linear equation
linear_equation3 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis3, y_axis3)

# Plot the regression line on top of scatterplot
plt.plot(x_axis3, regression_line3, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation3, (50,70), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere City Latitude vs. Humidity (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Northern_Hemisphere_Latitude_vs_Humidity_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.315309

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis4 = southern_weather_df['Lat']
y_axis4 = southern_weather_df['Humidity']

# Correlation equation
correlation4 = sts.pearsonr(x_axis4, y_axis4)
print(f"The r-value is: {round(correlation4[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis4, y_axis4)

# Calculate the regression line
regression_line4 = x_axis4 * slope + intercept

# Calculate the linear equation
linear_equation4 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis4, y_axis4)

# Plot the regression line on top of scatterplot
plt.plot(x_axis4, regression_line4, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation4, (-30,67.8), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere City Latitude vs. Humidity (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Southern_Hemisphere_Latitude_vs_Humidity_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.351608

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis5 = northern_weather_df['Lat']
y_axis5 = northern_weather_df['Cloudiness']

# Correlation equation
correlation5 = sts.pearsonr(x_axis5, y_axis5)
print(f"The r-value is: {round(correlation5[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis5, y_axis5)

# Calculate the regression line
regression_line5 = x_axis5 * slope + intercept

# Calculate the linear equation
linear_equation5 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis5, y_axis5)

# Plot the regression line on top of scatterplot
plt.plot(x_axis5, regression_line5, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation5, (50,45), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Northern_Hemisphere_Latitude_vs_Cloudiness_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.295311

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis6 = southern_weather_df['Lat']
y_axis6 = southern_weather_df['Cloudiness']

# Correlation equation
correlation6 = sts.pearsonr(x_axis6, y_axis6)
print(f"The r-value is: {round(correlation6[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis6, y_axis6)

# Calculate the regression line
regression_line6 = x_axis6 * slope + intercept

# Calculate the linear equation
linear_equation6 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis6, y_axis6)

# Plot the regression line on top of scatterplot
plt.plot(x_axis6, regression_line6, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation6, (-30,62), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Southern_Hemisphere_Latitude_vs_Cloudiness_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.29148

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis7 = northern_weather_df['Lat']
y_axis7 = northern_weather_df['Wind Speed']

# Correlation equation
correlation7 = sts.pearsonr(x_axis7, y_axis7)
print(f"The r-value is: {round(correlation7[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis7, y_axis7)

# Calculate the regression line
regression_line7 = x_axis7 * slope + intercept

# Calculate the linear equation
linear_equation7 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis7, y_axis7)

# Plot the regression line on top of scatterplot
plt.plot(x_axis7, regression_line7, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation7, (55,2.5), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Northern_Hemisphere_Latitude_vs_WindSpeed_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: 0.087784

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set axises 
x_axis8 = southern_weather_df['Lat']
y_axis8 = southern_weather_df['Wind Speed']

# Correlation equation
correlation8 = sts.pearsonr(x_axis8, y_axis8)
print(f"The r-value is: {round(correlation8[0],6)}")

# Find linear data by using x and y axis
(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_axis8, y_axis8)

# Calculate the regression line
regression_line8 = x_axis8 * slope + intercept

# Calculate the linear equation
linear_equation8 = "y = " + str(round(slope)) + "x + " + str(round(intercept))

# Plot the scatterplot data
plt.scatter(x_axis8, y_axis8)

# Plot the regression line on top of scatterplot
plt.plot(x_axis8, regression_line8, color="red")

# Print the linear equation on the scatterplot
plt.annotate(linear_equation8, (-30,6), fontsize=16, color="red")

# Set plot labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed (02/02/2021)")

# Save figure as output .png file
plt.savefig('output_data/Southern_Hemisphere_Latitude_vs_WindSpeed_Plot.png')

# Print plot
plt.show()
# Out:
# The r-value is: -0.178556
